# %% [markdown]
# ### Lung segmentation from Chest X-Ray dataset¶
# ## About the data:
#
# The dataset is made up of images and segmentated mask from two diffrent sources.
# There is a slight abnormality in naming convention of masks.
#
# Some images don't have their corresponding masks.
# Images from the Shenzhen dataset has apparently smaller lungs as compared to the Montgomery dataset.

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.

import numpy as np 
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread, createCLAHE 
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
image_path = os.path.join("/home/Desktop/archive/data/Lung Segmentation/CXR_png")
mask_path = os.path.join("/home/Desktop/archive/data/Lung Segmentation/masks")

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.
images = os.listdir(image_path)
mask = os.listdir(mask_path)
mask = [fName.split(".png")[0] for fName in mask]
image_file_name = [fName.split("_mask")[0] for fName in mask]

# %%
len(mask)
# Out:
# 704

# %%
len(images)
# Out:
# 800

# %%
check = [i for i in mask if "mask" in i]
print("Total mask that has modified name:",len(check))
# Out:
# Total mask that has modified name: 566

# %%
testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []
    
    if flag == "test":
        for i in tqdm(testing_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]
            
            im_array.append(im)
            mask_array.append(mask)
        
        return im_array,mask_array
    
    if flag == "train":
        for i in tqdm(training_files): 
            im = cv2.resize(cv2.imread(os.path.join(image_path,i.split("_mask")[0]+".png")),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i+".png")),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
#perform sanity check

def plotMask(X,y):
    sample = []
    
    for i in range(6):
        left = X[i]
        right = y[i]
        combined = np.hstack((left,right))
        sample.append(combined)
        
        
    for i in range(0,6,3):

        plt.figure(figsize=(25,10))
        
        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])
        
        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])
        
        
        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])
        
        plt.show()

# %%
# Load training and testing data
dim = 256*2
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)
# Out:
# 100%|██████████| 566/566 [00:51<00:00, 11.02it/s]
# 100%|██████████| 138/138 [00:39<00:00,  3.52it/s]

# %% [markdown]
# ### Perform Sanity Check¶
# It is prudent to perform sanity check of the data correspondance. It become a routine check-up after a while but it is very crucial to check if we had made a mistake in loading the data.

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %%
len(X_train)
# Out:
# 566

# %%
len(y_train)
# Out:
# 566

# %%
X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %% [markdown]
# ###Define the network and callbacks¶
# I am going to use my favourite segmentation network - U-Nets.

# %%
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import backend as keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler

def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256, 256, 1)):
    inputs = Input(input_size)

    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])

# %%
model = unet(input_size=(512, 512, 1))
model.compile(optimizer=Adam(learning_rate=1e-5), loss=dice_coef_loss,
              metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# 2024-07-09 15:42:31.503653: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-07-09 15:42:31.623784: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 512, 512,  │          0 │ -                 │
# │ (InputLayer)        │ 1)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 512, 512,  │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 512, 512,  │      9,248 │ conv2d[0][0]      │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 256, 256,  │          0 │ conv2d_1[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 256, 256,  │     18,496 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 256, 256,  │     36,928 │ conv2d_2[0][0]    │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 128, 128,  │          0 │ conv2d_3[0][0]    │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │     73,856 │ max_pooling2d_1[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │    147,584 │ conv2d_4[0][0]    │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 64, 64,    │          0 │ conv2d_5[0][0]    │
# │ (MaxPooling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │    295,168 │ max_pooling2d_2[… │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │    590,080 │ conv2d_6[0][0]    │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 32, 32,    │          0 │ conv2d_7[0][0]    │
# │ (MaxPooling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │  1,180,160 │ max_pooling2d_3[… │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 32,    │  2,359,808 │ conv2d_8[0][0]    │
# │                     │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose    │ (None, 64, 64,    │    524,544 │ conv2d_9[0][0]    │
# │ (Conv2DTranspose)   │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 512)              │            │ conv2d_7[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │  1,179,904 │ concatenate[0][0] │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 64, 64,    │    590,080 │ conv2d_10[0][0]   │
# │                     │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_1  │ (None, 128, 128,  │    131,200 │ conv2d_11[0][0]   │
# │ (Conv2DTranspose)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 128, 128,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 256)              │            │ conv2d_5[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 128, 128,  │    295,040 │ concatenate_1[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 128, 128,  │    147,584 │ conv2d_12[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_2  │ (None, 256, 256,  │     32,832 │ conv2d_13[0][0]   │
# │ (Conv2DTranspose)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 256, 256,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 128)              │            │ conv2d_3[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 256, 256,  │     73,792 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 256, 256,  │     36,928 │ conv2d_14[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_transpose_3  │ (None, 512, 512,  │      8,224 │ conv2d_15[0][0]   │
# │ (Conv2DTranspose)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 512, 512,  │          0 │ conv2d_transpose… │
# │ (Concatenate)       │ 64)               │            │ conv2d_1[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 512, 512,  │     18,464 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 512, 512,  │      9,248 │ conv2d_16[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 512, 512,  │         33 │ conv2d_17[0][0]   │
# │                     │ 1)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 7,759,521 (29.60 MB)
#  Trainable params: 7,759,521 (29.60 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
import numpy as np

weight_path = "{}_weights.best.weights.h5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1, 
                             save_best_only=True, mode='min', save_weights_only=True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5, 
                                   patience=3, verbose=1, mode='min', 
                                   min_delta=0.0001, cooldown=2, min_lr=1e-6)

early = EarlyStopping(monitor="val_loss", mode="min", patience=15)

callbacks_list = [checkpoint, early, reduceLROnPlat]

# %%
# from IPython.display import clear_output
from tensorflow.keras.optimizers import Adam 
from sklearn.model_selection import train_test_split

model.compile(optimizer=Adam(learning_rate=2e-4), 
              loss=[dice_coef_loss], 
              metrics=[dice_coef, 'binary_accuracy'])

train_vol, validation_vol, train_seg, validation_seg = train_test_split((images - 127.0) / 127.0, 
                                                                        (mask > 127).astype(np.float32), 
                                                                        test_size=0.1, random_state=2018)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol, train_seg, 
                                                            test_size=0.1, 
                                                            random_state=2018)

loss_history = model.fit(x=train_vol,
                         y=train_seg,
                         batch_size=16,
                         epochs=50,
                         validation_data=(test_vol, test_seg),
                         callbacks=callbacks_list)

# clear_output()
# Out:
# Epoch 1/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - binary_accuracy: 0.5675 - dice_coef: 0.3474 - loss: -0.3473
# Epoch 1: val_loss improved from inf to -0.50914, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 619s 17s/step - binary_accuracy: 0.5683 - dice_coef: 0.3481 - loss: -0.3480 - val_binary_accuracy: 0.6386 - val_dice_coef: 0.5091 - val_loss: -0.5091 - learning_rate: 2.0000e-04
# Epoch 2/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - binary_accuracy: 0.6336 - dice_coef: 0.5224 - loss: -0.5224
# Epoch 2: val_loss improved from -0.50914 to -0.54235, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 628s 17s/step - binary_accuracy: 0.6339 - dice_coef: 0.5229 - loss: -0.5229 - val_binary_accuracy: 0.6788 - val_dice_coef: 0.5423 - val_loss: -0.5423 - learning_rate: 2.0000e-04
# Epoch 3/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.7568 - dice_coef: 0.6138 - loss: -0.6138
# Epoch 3: val_loss improved from -0.54235 to -0.68280, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 608s 17s/step - binary_accuracy: 0.7576 - dice_coef: 0.6147 - loss: -0.6146 - val_binary_accuracy: 0.8287 - val_dice_coef: 0.6828 - val_loss: -0.6828 - learning_rate: 2.0000e-04
# Epoch 4/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.8292 - dice_coef: 0.6710 - loss: -0.6710
# Epoch 4: val_loss improved from -0.68280 to -0.75169, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 598s 17s/step - binary_accuracy: 0.8295 - dice_coef: 0.6716 - loss: -0.6716 - val_binary_accuracy: 0.8777 - val_dice_coef: 0.7517 - val_loss: -0.7517 - learning_rate: 2.0000e-04
# Epoch 5/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.8969 - dice_coef: 0.7970 - loss: -0.7970
# Epoch 5: val_loss improved from -0.75169 to -0.87892, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.8973 - dice_coef: 0.7978 - loss: -0.7978 - val_binary_accuracy: 0.9384 - val_dice_coef: 0.8789 - val_loss: -0.8789 - learning_rate: 2.0000e-04
# Epoch 6/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9241 - dice_coef: 0.8524 - loss: -0.8524
# Epoch 6: val_loss improved from -0.87892 to -0.89591, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 607s 17s/step - binary_accuracy: 0.9244 - dice_coef: 0.8528 - loss: -0.8528 - val_binary_accuracy: 0.9464 - val_dice_coef: 0.8959 - val_loss: -0.8959 - learning_rate: 2.0000e-04
# Epoch 7/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - binary_accuracy: 0.9349 - dice_coef: 0.8678 - loss: -0.8678
# Epoch 7: val_loss did not improve from -0.89591
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 612s 17s/step - binary_accuracy: 0.9347 - dice_coef: 0.8674 - loss: -0.8674 - val_binary_accuracy: 0.9381 - val_dice_coef: 0.8755 - val_loss: -0.8755 - learning_rate: 2.0000e-04
# Epoch 8/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 17s/step - binary_accuracy: 0.9415 - dice_coef: 0.8825 - loss: -0.8825
# Epoch 8: val_loss improved from -0.89591 to -0.90295, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 636s 18s/step - binary_accuracy: 0.9416 - dice_coef: 0.8827 - loss: -0.8827 - val_binary_accuracy: 0.9521 - val_dice_coef: 0.9029 - val_loss: -0.9029 - learning_rate: 2.0000e-04
# Epoch 9/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9552 - dice_coef: 0.9095 - loss: -0.9094
# Epoch 9: val_loss improved from -0.90295 to -0.93054, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9552 - dice_coef: 0.9096 - loss: -0.9096 - val_binary_accuracy: 0.9646 - val_dice_coef: 0.9305 - val_loss: -0.9305 - learning_rate: 2.0000e-04
# Epoch 10/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9626 - dice_coef: 0.9252 - loss: -0.9252
# Epoch 10: val_loss did not improve from -0.93054
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9626 - dice_coef: 0.9252 - loss: -0.9252 - val_binary_accuracy: 0.9638 - val_dice_coef: 0.9292 - val_loss: -0.9292 - learning_rate: 2.0000e-04
# Epoch 11/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9661 - dice_coef: 0.9326 - loss: -0.9326
# Epoch 11: val_loss improved from -0.93054 to -0.94378, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9661 - dice_coef: 0.9326 - loss: -0.9326 - val_binary_accuracy: 0.9710 - val_dice_coef: 0.9438 - val_loss: -0.9438 - learning_rate: 2.0000e-04
# Epoch 12/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9706 - dice_coef: 0.9406 - loss: -0.9406
# Epoch 12: val_loss improved from -0.94378 to -0.94500, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 603s 17s/step - binary_accuracy: 0.9706 - dice_coef: 0.9405 - loss: -0.9406 - val_binary_accuracy: 0.9716 - val_dice_coef: 0.9450 - val_loss: -0.9450 - learning_rate: 2.0000e-04
# Epoch 13/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9704 - dice_coef: 0.9410 - loss: -0.9410
# Epoch 13: val_loss did not improve from -0.94500
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9704 - dice_coef: 0.9410 - loss: -0.9410 - val_binary_accuracy: 0.9719 - val_dice_coef: 0.9437 - val_loss: -0.9437 - learning_rate: 2.0000e-04
# Epoch 14/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9715 - dice_coef: 0.9440 - loss: -0.9440
# Epoch 14: val_loss improved from -0.94500 to -0.94860, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 621s 17s/step - binary_accuracy: 0.9715 - dice_coef: 0.9440 - loss: -0.9440 - val_binary_accuracy: 0.9732 - val_dice_coef: 0.9486 - val_loss: -0.9486 - learning_rate: 2.0000e-04
# Epoch 15/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9748 - dice_coef: 0.9500 - loss: -0.9500
# Epoch 15: val_loss improved from -0.94860 to -0.95459, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9748 - dice_coef: 0.9500 - loss: -0.9500 - val_binary_accuracy: 0.9770 - val_dice_coef: 0.9546 - val_loss: -0.9546 - learning_rate: 2.0000e-04
# Epoch 16/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9754 - dice_coef: 0.9507 - loss: -0.9507
# Epoch 16: val_loss did not improve from -0.95459
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9754 - dice_coef: 0.9508 - loss: -0.9508 - val_binary_accuracy: 0.9765 - val_dice_coef: 0.9531 - val_loss: -0.9531 - learning_rate: 2.0000e-04
# Epoch 17/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9765 - dice_coef: 0.9529 - loss: -0.9529
# Epoch 17: val_loss improved from -0.95459 to -0.95708, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9765 - dice_coef: 0.9529 - loss: -0.9529 - val_binary_accuracy: 0.9780 - val_dice_coef: 0.9571 - val_loss: -0.9571 - learning_rate: 2.0000e-04
# Epoch 18/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9778 - dice_coef: 0.9553 - loss: -0.9553
# Epoch 18: val_loss did not improve from -0.95708
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9778 - dice_coef: 0.9553 - loss: -0.9553 - val_binary_accuracy: 0.9761 - val_dice_coef: 0.9523 - val_loss: -0.9523 - learning_rate: 2.0000e-04
# Epoch 19/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9759 - dice_coef: 0.9521 - loss: -0.9521
# Epoch 19: val_loss improved from -0.95708 to -0.95826, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 607s 17s/step - binary_accuracy: 0.9759 - dice_coef: 0.9521 - loss: -0.9521 - val_binary_accuracy: 0.9788 - val_dice_coef: 0.9583 - val_loss: -0.9583 - learning_rate: 2.0000e-04
# Epoch 20/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9782 - dice_coef: 0.9560 - loss: -0.9560
# Epoch 20: val_loss did not improve from -0.95826
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9782 - dice_coef: 0.9560 - loss: -0.9560 - val_binary_accuracy: 0.9783 - val_dice_coef: 0.9567 - val_loss: -0.9567 - learning_rate: 2.0000e-04
# Epoch 21/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9783 - dice_coef: 0.9565 - loss: -0.9565
# Epoch 21: val_loss improved from -0.95826 to -0.96012, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9783 - dice_coef: 0.9565 - loss: -0.9565 - val_binary_accuracy: 0.9796 - val_dice_coef: 0.9601 - val_loss: -0.9601 - learning_rate: 2.0000e-04
# Epoch 22/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9789 - dice_coef: 0.9577 - loss: -0.9577
# Epoch 22: val_loss did not improve from -0.96012
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9789 - dice_coef: 0.9577 - loss: -0.9577 - val_binary_accuracy: 0.9785 - val_dice_coef: 0.9586 - val_loss: -0.9586 - learning_rate: 2.0000e-04
# Epoch 23/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9786 - dice_coef: 0.9572 - loss: -0.9572
# Epoch 23: val_loss improved from -0.96012 to -0.96092, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9786 - dice_coef: 0.9572 - loss: -0.9572 - val_binary_accuracy: 0.9799 - val_dice_coef: 0.9609 - val_loss: -0.9609 - learning_rate: 2.0000e-04
# Epoch 24/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9790 - dice_coef: 0.9582 - loss: -0.9582
# Epoch 24: val_loss did not improve from -0.96092
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9790 - dice_coef: 0.9582 - loss: -0.9582 - val_binary_accuracy: 0.9793 - val_dice_coef: 0.9596 - val_loss: -0.9596 - learning_rate: 2.0000e-04
# Epoch 25/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9789 - dice_coef: 0.9572 - loss: -0.9572
# Epoch 25: val_loss improved from -0.96092 to -0.96112, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9789 - dice_coef: 0.9573 - loss: -0.9573 - val_binary_accuracy: 0.9800 - val_dice_coef: 0.9611 - val_loss: -0.9611 - learning_rate: 2.0000e-04
# Epoch 26/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9798 - dice_coef: 0.9595 - loss: -0.9595
# Epoch 26: val_loss did not improve from -0.96112
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9797 - dice_coef: 0.9595 - loss: -0.9595 - val_binary_accuracy: 0.9796 - val_dice_coef: 0.9604 - val_loss: -0.9604 - learning_rate: 2.0000e-04
# Epoch 27/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9807 - dice_coef: 0.9611 - loss: -0.9611
# Epoch 27: val_loss did not improve from -0.96112
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 603s 17s/step - binary_accuracy: 0.9807 - dice_coef: 0.9611 - loss: -0.9611 - val_binary_accuracy: 0.9794 - val_dice_coef: 0.9603 - val_loss: -0.9603 - learning_rate: 2.0000e-04
# Epoch 28/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9796 - dice_coef: 0.9598 - loss: -0.9598
# Epoch 28: val_loss improved from -0.96112 to -0.96139, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9796 - dice_coef: 0.9598 - loss: -0.9598 - val_binary_accuracy: 0.9802 - val_dice_coef: 0.9614 - val_loss: -0.9614 - learning_rate: 2.0000e-04
# Epoch 29/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9821 - dice_coef: 0.9641 - loss: -0.9641
# Epoch 29: val_loss improved from -0.96139 to -0.96265, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 621s 17s/step - binary_accuracy: 0.9821 - dice_coef: 0.9640 - loss: -0.9640 - val_binary_accuracy: 0.9811 - val_dice_coef: 0.9626 - val_loss: -0.9626 - learning_rate: 2.0000e-04
# Epoch 30/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9817 - dice_coef: 0.9632 - loss: -0.9632
# Epoch 30: val_loss did not improve from -0.96265
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9817 - dice_coef: 0.9632 - loss: -0.9632 - val_binary_accuracy: 0.9805 - val_dice_coef: 0.9620 - val_loss: -0.9620 - learning_rate: 2.0000e-04
# Epoch 31/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9819 - dice_coef: 0.9631 - loss: -0.9631
# Epoch 31: val_loss improved from -0.96265 to -0.96303, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9819 - dice_coef: 0.9631 - loss: -0.9631 - val_binary_accuracy: 0.9811 - val_dice_coef: 0.9630 - val_loss: -0.9630 - learning_rate: 2.0000e-04
# Epoch 32/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9814 - dice_coef: 0.9637 - loss: -0.9637
# Epoch 32: val_loss did not improve from -0.96303
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9814 - dice_coef: 0.9637 - loss: -0.9637 - val_binary_accuracy: 0.9780 - val_dice_coef: 0.9579 - val_loss: -0.9579 - learning_rate: 2.0000e-04
# Epoch 33/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9806 - dice_coef: 0.9613 - loss: -0.9613
# Epoch 33: val_loss improved from -0.96303 to -0.96308, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9806 - dice_coef: 0.9613 - loss: -0.9613 - val_binary_accuracy: 0.9812 - val_dice_coef: 0.9631 - val_loss: -0.9631 - learning_rate: 2.0000e-04
# Epoch 34/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9816 - dice_coef: 0.9631 - loss: -0.9631
# Epoch 34: val_loss improved from -0.96308 to -0.96316, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9816 - dice_coef: 0.9631 - loss: -0.9631 - val_binary_accuracy: 0.9813 - val_dice_coef: 0.9632 - val_loss: -0.9632 - learning_rate: 2.0000e-04
# Epoch 35/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9821 - dice_coef: 0.9643 - loss: -0.9643
# Epoch 35: val_loss did not improve from -0.96316
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9821 - dice_coef: 0.9643 - loss: -0.9643 - val_binary_accuracy: 0.9801 - val_dice_coef: 0.9617 - val_loss: -0.9617 - learning_rate: 2.0000e-04
# Epoch 36/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9820 - dice_coef: 0.9640 - loss: -0.9640
# Epoch 36: val_loss did not improve from -0.96316
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9820 - dice_coef: 0.9640 - loss: -0.9640 - val_binary_accuracy: 0.9811 - val_dice_coef: 0.9630 - val_loss: -0.9630 - learning_rate: 2.0000e-04
# Epoch 37/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9829 - dice_coef: 0.9658 - loss: -0.9658
# Epoch 37: val_loss improved from -0.96316 to -0.96418, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9829 - dice_coef: 0.9658 - loss: -0.9658 - val_binary_accuracy: 0.9817 - val_dice_coef: 0.9642 - val_loss: -0.9642 - learning_rate: 2.0000e-04
# Epoch 38/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9825 - dice_coef: 0.9647 - loss: -0.9647
# Epoch 38: val_loss did not improve from -0.96418
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 603s 17s/step - binary_accuracy: 0.9825 - dice_coef: 0.9647 - loss: -0.9647 - val_binary_accuracy: 0.9801 - val_dice_coef: 0.9616 - val_loss: -0.9616 - learning_rate: 2.0000e-04
# Epoch 39/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9821 - dice_coef: 0.9645 - loss: -0.9645
# Epoch 39: val_loss did not improve from -0.96418
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 603s 17s/step - binary_accuracy: 0.9821 - dice_coef: 0.9645 - loss: -0.9645 - val_binary_accuracy: 0.9810 - val_dice_coef: 0.9632 - val_loss: -0.9632 - learning_rate: 2.0000e-04
# Epoch 40/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9822 - dice_coef: 0.9647 - loss: -0.9647
# Epoch 40: val_loss did not improve from -0.96418
#
# Epoch 40: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9822 - dice_coef: 0.9647 - loss: -0.9647 - val_binary_accuracy: 0.9812 - val_dice_coef: 0.9633 - val_loss: -0.9633 - learning_rate: 2.0000e-04
# Epoch 41/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9825 - dice_coef: 0.9653 - loss: -0.9653
# Epoch 41: val_loss improved from -0.96418 to -0.96419, saving model to cxr_reg_weights.best.weights.h5
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9825 - dice_coef: 0.9653 - loss: -0.9653 - val_binary_accuracy: 0.9816 - val_dice_coef: 0.9642 - val_loss: -0.9642 - learning_rate: 1.0000e-04
# Epoch 42/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9827 - dice_coef: 0.9656 - loss: -0.9656
# Epoch 42: val_loss did not improve from -0.96419
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 604s 17s/step - binary_accuracy: 0.9827 - dice_coef: 0.9657 - loss: -0.9657 - val_binary_accuracy: 0.9810 - val_dice_coef: 0.9631 - val_loss: -0.9631 - learning_rate: 1.0000e-04
# Epoch 43/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9828 - dice_coef: 0.9659 - loss: -0.9659
# Epoch 43: val_loss did not improve from -0.96419
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9829 - dice_coef: 0.9660 - loss: -0.9660 - val_binary_accuracy: 0.9813 - val_dice_coef: 0.9634 - val_loss: -0.9634 - learning_rate: 1.0000e-04
# Epoch 44/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9837 - dice_coef: 0.9675 - loss: -0.9675
# Epoch 44: val_loss did not improve from -0.96419
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 606s 17s/step - binary_accuracy: 0.9837 - dice_coef: 0.9675 - loss: -0.9675 - val_binary_accuracy: 0.9809 - val_dice_coef: 0.9629 - val_loss: -0.9629 - learning_rate: 1.0000e-04
# Epoch 45/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9846 - dice_coef: 0.9694 - loss: -0.9694
# Epoch 45: val_loss did not improve from -0.96419
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 606s 17s/step - binary_accuracy: 0.9846 - dice_coef: 0.9693 - loss: -0.9693 - val_binary_accuracy: 0.9816 - val_dice_coef: 0.9641 - val_loss: -0.9641 - learning_rate: 5.0000e-05
# Epoch 46/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9840 - dice_coef: 0.9683 - loss: -0.9683
# Epoch 46: val_loss did not improve from -0.96419
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 606s 17s/step - binary_accuracy: 0.9840 - dice_coef: 0.9683 - loss: -0.9683 - val_binary_accuracy: 0.9816 - val_dice_coef: 0.9640 - val_loss: -0.9640 - learning_rate: 5.0000e-05
# Epoch 47/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9850 - dice_coef: 0.9700 - loss: -0.9700
# Epoch 47: val_loss did not improve from -0.96419
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9849 - dice_coef: 0.9700 - loss: -0.9700 - val_binary_accuracy: 0.9816 - val_dice_coef: 0.9640 - val_loss: -0.9640 - learning_rate: 5.0000e-05
# Epoch 48/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9847 - dice_coef: 0.9691 - loss: -0.9691
# Epoch 48: val_loss did not improve from -0.96419
#
# Epoch 48: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9847 - dice_coef: 0.9691 - loss: -0.9691 - val_binary_accuracy: 0.9814 - val_dice_coef: 0.9636 - val_loss: -0.9636 - learning_rate: 5.0000e-05
# Epoch 49/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9838 - dice_coef: 0.9676 - loss: -0.9676
# Epoch 49: val_loss did not improve from -0.96419
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 605s 17s/step - binary_accuracy: 0.9838 - dice_coef: 0.9677 - loss: -0.9677 - val_binary_accuracy: 0.9814 - val_dice_coef: 0.9638 - val_loss: -0.9638 - learning_rate: 2.5000e-05
# Epoch 50/50
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 16s/step - binary_accuracy: 0.9840 - dice_coef: 0.9683 - loss: -0.9683
# Epoch 50: val_loss did not improve from -0.96419
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 621s 17s/step - binary_accuracy: 0.9840 - dice_coef: 0.9683 - loss: -0.9683 - val_binary_accuracy: 0.9815 - val_dice_coef: 0.9639 - val_loss: -0.9639 - learning_rate: 2.5000e-05

# %% [markdown]
# # Plot the metric and evaluate

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss',color='red')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-', 
         label = 'Accuracy',color = 'red')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

plt.savefig('training_results.png')  # Save the figure to the working directory
plt.show()
